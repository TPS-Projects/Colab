# %% [markdown]
# <a href="https://colab.research.google.com/github/TPS-Projects/Colab/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58,12,25,35,37,42,50,55,15,85,46,28,15],
        "Sex": ["male", "male", "female","male", "male", "female","male", "male", "female","male", "male", "female","male", "male", "female"],
    }
)
df
# Out:
#                         Name  Age     Sex
# 0    Braund, Mr. Owen Harris   22    male
# 1   Allen, Mr. William Henry   35    male
# 2   Bonnell, Miss. Elizabeth   58  female
# 3   Bonnell, Miss. Elizabeth   12    male
# 4   Bonnell, Miss. Elizabeth   25    male
# 5   Bonnell, Miss. Elizabeth   35  female
# 6   Bonnell, Miss. Elizabeth   37    male
# 7   Bonnell, Miss. Elizabeth   42    male
# 8   Bonnell, Miss. Elizabeth   50  female
# 9   Bonnell, Miss. Elizabeth   55    male
# 10  Bonnell, Miss. Elizabeth   15    male
# 11  Bonnell, Miss. Elizabeth   85  female
# 12  Bonnell, Miss. Elizabeth   46    male
# 13  Bonnell, Miss. Elizabeth   28    male
# 14  Bonnell, Miss. Elizabeth   15  female

# %%
df ["Age"]
# Out:
# 0     22
# 1     35
# 2     58
# 3     12
# 4     25
# 5     35
# 6     37
# 7     42
# 8     50
# 9     55
# 10    15
# 11    85
# 12    46
# 13    28
# 14    15
# Name: Age, dtype: int64

# %%
age= pd.Series([22,35,58], name= "Ages")
age
# Out:
# 0    22
# 1    35
# 2    58
# Name: Ages, dtype: int64

# %%
df["Age"].max()
# Out:
# 85

# %%
df["Age"].min()
# Out:
# 12

# %%
df.describe()
# Out:
#              Age
# count  15.000000
# mean   37.333333
# std    19.627483
# min    12.000000
# 25%    23.500000
# 50%    35.000000
# 75%    48.000000
# max    85.000000

# %%
df["Age"]. mean()
# Out:
# np.float64(37.333333333333336)

# %%
print ("hello")
# Out:
# hello

# %%
agesex= df[["Age", "Sex"]]
agesex
# Out:
#     Age     Sex
# 0    22    male
# 1    35    male
# 2    58  female
# 3    12    male
# 4    25    male
# 5    35  female
# 6    37    male
# 7    42    male
# 8    50  female
# 9    55    male
# 10   15    male
# 11   85  female
# 12   46    male
# 13   28    male
# 14   15  female

# %%
df.shape
# Out:
# (15, 3)

# %%
type(df [["Age"]])
# Out:
# pandas.core.frame.DataFrame

# %%
Above_35 = df[df ["Age"]>35]
Above_35
# Out:
#                         Name  Age     Sex
# 2   Bonnell, Miss. Elizabeth   58  female
# 6   Bonnell, Miss. Elizabeth   37    male
# 7   Bonnell, Miss. Elizabeth   42    male
# 8   Bonnell, Miss. Elizabeth   50  female
# 9   Bonnell, Miss. Elizabeth   55    male
# 11  Bonnell, Miss. Elizabeth   85  female
# 12  Bonnell, Miss. Elizabeth   46    male

# %%
Above_35.head()
# Out:
#                        Name  Age     Sex
# 2  Bonnell, Miss. Elizabeth   58  female
# 6  Bonnell, Miss. Elizabeth   37    male
# 7  Bonnell, Miss. Elizabeth   42    male
# 8  Bonnell, Miss. Elizabeth   50  female
# 9  Bonnell, Miss. Elizabeth   55    male

# %%
Above_35.shape
# Out:
# (7, 3)

# %%
Senior = df.loc[df ["Age"] >65, "Name"]
Senior
# Out:
# 11    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd


Air_Quality = pd.read_csv ('/content/drive/My Drive/Colab Notebooks/Datasets/air_quality_no2.csv', index_col=0, parse_dates= True)
Air_Quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
import matplotlib.pyplot as plt
Air_Quality.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Air_Quality["station_paris"].plot()
plt.show()

# %%
Air_Quality.plot.box()
plt.show()

# %%
axs = Air_Quality.plot.area(figsize=(12, 4), subplots=False)
axs.set_ylabel("NO² Concentration")
axs.set_xlabel("data")

plt.show()

# %%
Air_Quality ["Por_m³"] =  Air_Quality ["station_london"]*1882
Air_Quality.head()
# Out:
#                      station_antwerp  station_paris  station_london   Por_m³
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0  43286.0
# 2019-05-07 03:00:00             50.5           25.0            19.0  35758.0
# 2019-05-07 04:00:00             45.0           27.7            19.0  35758.0
# 2019-05-07 05:00:00              NaN           50.4            16.0  30112.0
# 2019-05-07 06:00:00              NaN           61.9             NaN      NaN
